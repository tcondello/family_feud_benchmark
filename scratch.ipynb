# %%
import json

llm_response = open("responses/openAI_response_list.json")
score_card = open("questions/question_list.json")
res_data = json.load(llm_response)
score_data = json.load(score_card)

# %%
for question in score_data.get('questions'):
    if question.get('question') in res_data:
        print(res_data)

# %%
for res in res_data:
    for k,v in res.items():
        print(k)
# Out:
# Name an occupation that begins with the letter 'J.'
# Name something that might be brewing.
# Name something with teeth.
# Name the most useful body part that begins with the letter 'L.'
# Name something an athlete might break.
# Name something associated with vampires.
# Name something in a bakery a baker might call his wife.
# Name something in a person's closet that only comes out on special occasions.
# Name something you might see a commercial for during a baseball game.
# If your dog ran away, name something you'd be surprised he took with him.
# Name an occasion where parents force their kids to wear a certain outfit.
# Name a reason that someone might ride their bike to work.
# Name something that might come out of your nose when you laugh.
# Name qualities of a bad boss.
# Name a food dogs love just as much as humans do.
# Name something that shakes, rattles, and rolls.
# Other than feet, name something that runs.
# Name a word that rhymes with “election.”
# ...
